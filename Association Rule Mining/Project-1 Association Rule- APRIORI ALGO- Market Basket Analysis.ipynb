# %% [markdown]
# # APRIORI ALGO

# %%
#pip install mlxtend

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder

# %% [raw]
# # making each customers shopping items an identical list
# trans = []
# for i in range(0, 7501):
#     trans.append([str(data.values[i,j]) for j in range(0, 20)])
#
# # conveting it into an numpy array
# trans = np.array(trans)
#
# # checking the shape of the array
# print(trans.shape)

# %%
dataset = [
            ['whole milk','butter', 'chocolate', 'pastry' , 'Eggs' , 'Yogurts'],
            ['ballons','butter', 'chocolate', 'pastry' , 'Eggs' , 'Yogurts'],
            ['whole milk','Apple', 'pastry' , 'Eggs' ],
            ['whole milk','Unicorn', 'Corn', 'pastry'  , 'Yogurts'],
            ['Corn','butter', 'cake', 'pastry' , 'Ice creams' , 'Eggs']
    
            ]

# %%
#import warnings
#warnings.filterwarnings('ignore')

# %%
dataset
# Out:
# [['whole milk', 'butter', 'chocolate', 'pastry', 'Eggs', 'Yogurts'],
#  ['ballons', 'butter', 'chocolate', 'pastry', 'Eggs', 'Yogurts'],
#  ['whole milk', 'Apple', 'pastry', 'Eggs'],
#  ['whole milk', 'Unicorn', 'Corn', 'pastry', 'Yogurts'],
#  ['Corn', 'butter', 'cake', 'pastry', 'Ice creams', 'Eggs']]

# %% [raw]
# #fit and transform method

# %%
te = TransactionEncoder()

# %%
te
# Out:
# TransactionEncoder()

# %%
te_ary = te.fit(dataset).transform(dataset)

# %%
te_ary
# Out:
# array([[False, False,  True, False, False,  True, False,  True, False,
#          True,  True,  True],
#        [False, False,  True, False, False,  True,  True,  True, False,
#          True,  True, False],
#        [ True, False,  True, False, False, False, False, False, False,
#         False,  True,  True],
#        [False,  True, False, False,  True,  True, False, False, False,
#         False,  True,  True],
#        [False,  True,  True,  True, False, False, False,  True,  True,
#         False,  True, False]])

# %%
df = pd.DataFrame(te_ary, columns = te.columns_)

# %%
df
# Out:
#    Apple   Corn   Eggs  Ice creams  Unicorn  Yogurts  ballons  butter   cake  \
# 0  False  False   True       False    False     True    False    True  False
# 1  False  False   True       False    False     True     True    True  False
# 2   True  False   True       False    False    False    False   False  False
# 3  False   True  False       False     True     True    False   False  False
# 4  False   True   True        True    False    False    False    True   True
#
#    chocolate  pastry  whole milk
# 0       True    True        True
# 1       True    True       False
# 2      False    True        True
# 3      False    True        True
# 4      False    True       False

# %%
from mlxtend.frequent_patterns import apriori
frequent_itemsets = apriori (df ,min_support = 0.6 , use_colnames=True)
frequent_itemsets
# Out:
#     support                itemsets
# 0       0.8                  (Eggs)
# 1       0.6               (Yogurts)
# 2       0.6                (butter)
# 3       1.0                (pastry)
# 4       0.6            (whole milk)
# 5       0.6          (butter, Eggs)
# 6       0.8          (Eggs, pastry)
# 7       0.6       (Yogurts, pastry)
# 8       0.6        (butter, pastry)
# 9       0.6    (whole milk, pastry)
# 10      0.6  (butter, Eggs, pastry)

# %% [markdown]
# # Association Rule Mining

# %%
from mlxtend.frequent_patterns import association_rules
res = association_rules(frequent_itemsets, metric =  "confidence" , min_threshold = 0.7)
res
# Out:
#          antecedents       consequents  antecedent support  \
# 0           (butter)            (Eggs)                 0.6
# 1             (Eggs)          (butter)                 0.8
# 2             (Eggs)          (pastry)                 0.8
# 3           (pastry)            (Eggs)                 1.0
# 4          (Yogurts)          (pastry)                 0.6
# 5           (butter)          (pastry)                 0.6
# 6       (whole milk)          (pastry)                 0.6
# 7     (butter, Eggs)          (pastry)                 0.6
# 8   (butter, pastry)            (Eggs)                 0.6
# 9     (Eggs, pastry)          (butter)                 0.8
# 10          (butter)    (Eggs, pastry)                 0.6
# 11            (Eggs)  (butter, pastry)                 0.8
#
#     consequent support  support  confidence  lift  leverage  conviction
# 0                  0.8      0.6        1.00  1.25      0.12         inf
# ...

# %%
res1 =res[  [ 'antecedents', 'consequents', 'support', 'confidence', 'lift']]
res1
# Out:
#          antecedents       consequents  support  confidence  lift
# 0           (butter)            (Eggs)      0.6        1.00  1.25
# 1             (Eggs)          (butter)      0.6        0.75  1.25
# 2             (Eggs)          (pastry)      0.8        1.00  1.00
# 3           (pastry)            (Eggs)      0.8        0.80  1.00
# 4          (Yogurts)          (pastry)      0.6        1.00  1.00
# 5           (butter)          (pastry)      0.6        1.00  1.00
# 6       (whole milk)          (pastry)      0.6        1.00  1.00
# 7     (butter, Eggs)          (pastry)      0.6        1.00  1.00
# 8   (butter, pastry)            (Eggs)      0.6        1.00  1.25
# 9     (Eggs, pastry)          (butter)      0.6        0.75  1.25
# 10          (butter)    (Eggs, pastry)      0.6        1.00  1.25
# 11            (Eggs)  (butter, pastry)      0.6        0.75  1.25

# %%
res2 = res1[res1['confidence'] >=1]
res2
# Out:
#          antecedents     consequents  support  confidence  lift
# 0           (butter)          (Eggs)      0.6         1.0  1.25
# 2             (Eggs)        (pastry)      0.8         1.0  1.00
# 4          (Yogurts)        (pastry)      0.6         1.0  1.00
# 5           (butter)        (pastry)      0.6         1.0  1.00
# 6       (whole milk)        (pastry)      0.6         1.0  1.00
# 7     (butter, Eggs)        (pastry)      0.6         1.0  1.00
# 8   (butter, pastry)          (Eggs)      0.6         1.0  1.25
# 10          (butter)  (Eggs, pastry)      0.6         1.0  1.25
